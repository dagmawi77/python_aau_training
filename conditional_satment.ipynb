# %%
paid = True
if paid== True:
    print("You have Paid")
# Out:
# You have Paid

# %%
total_pay=10000  
if paid == True:   
    print("you have paid!")  
daysWork = 10  
payment_per_day = None  
if daysWork >= 1:   
    payment_per_day = total_pay/daysWork
# Out:
# you have paid!

# %%
Paid=True
if paid == True:
    print("you have paid!")
Paid=True
if paid:
   print("you have paid!")
# Out:
# you have paid!
# you have paid!

# %%
bill=1000
payment=1000
if bill > payment:

    print("you have NOT paid in full!")
else:
    print("you have paid it in full !")
# Out:
# you have paid it in full !

# %%
consumption =100
Penality=False
if consumption < 50 :
    print("under consumed")
else:
    print("over consumed!")
Penality= True
# Out:
# over consumed!

# %%
payment= 10
if payment < 50:
    print("you paid less than half")
elif payment < 80:
    print("you paid more than half")
else:
    print("you paid in full")
# Out:
# you paid less than half

# %%
payment= 10
if payment < 50:
    print("you paid than half")
elif payment == 50 or payment < 80:
    print("you paid more than half")
else:
    print("you paid in full")
# Out:
# you paid than half

# %%
payment= 10
if payment < 50:
    print("you paid less than half")
if payment < 80:
    print("you paid more than half")
else:
    print("you paid in full")
# Out:
# you paid less than half
# you paid more than half

# %%
payment= 10
if payment < 50:
    print("you paid less than half")
elif payment < 80:
    print("you paid more than half")
elif payment < 90:
    print("you paid more than half")
else:
    print("you paid in full")
# Out:
# you paid less than half

# %%
payment= 10
if payment < 50:
    print("you paid less than half")
if payment == 50 and payment < 80:
    print("you paid more than half")
else:
    print("you paid in full")
# Out:
# you paid less than half
# you paid in full

# %%
consumption= 10
if consumption < 50:
    userPriority = input("what is the user priority")
if userPriority == "low" :
    print("you can pay later")
elif userPriority == "high" :
    print("you need to get you line checked")
else:
    print("all is well")
# Out:
# you can pay later
